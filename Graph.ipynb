# %%
import networkx as nx
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
G = nx.barabasi_albert_graph(100,5)

# %%
plt.figure(figsize=(20,10))
nx.draw_networkx(G)

# %%
G.number_of_edges()
# Out:
# 475

# %%
G.number_of_nodes()
# Out:
# 100

# %%
#add lollipop graph
lol = nx.lollipop_graph(10,20)
nx.draw_networkx(lol)
plt.figure(figsize=(20,10))

# %%
lol.number_of_edges()
# Out:
# 65

# %%
lol.number_of_nodes()
# Out:
# 30

# %%
! ls -l
# Out:
# total 7016
# -rw-r--r--  1 theophilus  staff       72 Nov  8 22:23 Analyzing Graphs.ipynb
# -rw-r--r--  1 theophilus  staff     5114 Nov  8 20:15 Course Layout.ipynb
# -rw-r--r--  1 theophilus  staff    28821 Nov 10 20:12 Creating Graphs.ipynb
# -rw-r--r--  1 theophilus  staff     1175 Nov  8 22:37 Documentations.ipynb
# -rw-r--r--  1 theophilus  staff     2311 Nov  8 22:26 Drawing Graphs.ipynb
# -rw-r--r--  1 theophilus  staff     3053 Nov  8 22:33 Exceptions in NetworkX.ipynb
# -rw-r--r--  1 theophilus  staff     2474 Nov  8 22:22 Graph Generators.ipynb
# -rw-r--r--  1 theophilus  staff   416505 Nov 21 19:52 Graph.ipynb
# -rw-r--r--  1 theophilus  staff  2520405 Nov  8 19:22 Max-Flow-Min-Cut-Problem.ipynb
# -rw-r--r--  1 theophilus  staff   105989 Nov  8 01:03 MaxFlow-MinCut-Problem.ipynb
# -rw-r--r--@ 1 theophilus  staff   467147 Oct 25  2014 NYC_Social_Media_Usage.csv
# -rw-r--r--  1 theophilus  staff     7192 Nov 10 17:44 Overview of NetworkX.ipynb
# ...
